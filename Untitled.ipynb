# %%
import pandas as pd

# %%
data = pd.read_csv('movie_metadata.csv')

# %%
data.groupby('actor_1_name').count().sort_values('color', ascending = False)
# Out:
#                         color  director_name  num_critic_for_reviews  \
# actor_1_name
# Robert De Niro             49             49                      48
# Johnny Depp                41             41                      41
# Nicolas Cage               33             33                      33
# J.K. Simmons               31             31                      31
# Denzel Washington          30             30                      30
# Matt Damon                 30             30                      30
# Bruce Willis               30             30                      30
# Liam Neeson                29             29                      29
# Robin Williams             27             27                      27
# Steve Buscemi              27             27                      27
# Harrison Ford              27             27                      27
# Jason Statham              26             26                      26
# ...

# %%
data
# Out:
#                  color       director_name  num_critic_for_reviews  duration  \
# 0                Color       James Cameron                   723.0     178.0
# 1                Color      Gore Verbinski                   302.0     169.0
# 2                Color          Sam Mendes                   602.0     148.0
# 3                Color   Christopher Nolan                   813.0     164.0
# 4                  NaN         Doug Walker                     NaN       NaN
# 5                Color      Andrew Stanton                   462.0     132.0
# 6                Color           Sam Raimi                   392.0     156.0
# 7                Color        Nathan Greno                   324.0     100.0
# 8                Color         Joss Whedon                   635.0     141.0
# 9                Color         David Yates                   375.0     153.0
# 10               Color         Zack Snyder                   673.0     183.0
# ...

# %%
data.groupby('actor_3_name').count().sort_values('color', ascending = False)
# Out:
#                      color  director_name  num_critic_for_reviews  duration  \
# actor_3_name
# John Heard               8              8                       8         8
# Ben Mendelsohn           8              8                       8         8
# Steve Coogan             8              8                       8         8
# Anne Hathaway            7              7                       7         7
# Stephen Root             7              7                       7         7
# Robert Duvall            7              7                       7         7
# Lois Maxwell             7              7                       7         7
# Kirsten Dunst            7              7                       7         7
# Jon Gries                7              7                       7         7
# Sam Shepard              7              7                       7         7
# Hope Davis               6              6                       6         6
# ...

# %%
t1 = data[data['actor_1_name'] == 'Morgan Freeman']
t2 = data[data['actor_2_name'] == 'Morgan Freeman']
t3 = data[data['actor_3_name'] == 'Morgan Freeman']

# %%
full = pd.DataFrame()
full = pd.concat([t1,t2])
full = pd.concat([full,t3])

# %%
full =full.reset_index(drop=True)

# %%
d = []
for i in full.genres:   
    d.append(i.split('|'))

# %%
#[i for t in d] 
m = [i for t in d for i in t]

# %%
from collections import Counter
gen_list = Counter(m)

# %%
gen_list
# Out:
# Counter({'Action': 16,
#          'Adventure': 9,
#          'Mystery': 9,
#          'Sci-Fi': 6,
#          'Drama': 33,
#          'History': 7,
#          'Comedy': 11,
#          'Romance': 4,
#          'Thriller': 21,
#          'Crime': 16,
#          'Horror': 1,
#          'Animation': 1,
#          'Family': 5,
#          'Fantasy': 3,
#          'Documentary': 1,
#          'Biography': 1,
#          'Sport': 2,
#          'War': 2,
#          'Western': 1})

# %%
full['is_drama'] = full.apply(isDrama, axis = 1)

# %%
def isDrama(row):
    t = row['genres'].split("|")
    return 'Drama' in t

# %%
full.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'is_drama'],
#       dtype='object')

# %%
dramaa = full[full['is_drama'] == True]
len(dramaa)
# Out:
# 33

# %%
pgdrama = len(dramaa[dramaa['content_rating'] == 'PG-13'])
pgdrama
# Out:
# 15

# %%
pg13 = len(full[full['content_rating'] == 'PG-13'])
pg13
# Out:
# 22

# %%
# Import the library
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
venn2(subsets = (18,7,15),  set_labels = ('Drama', 'PG-13'))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
Counter(full['content_rating'])
# Out:
# Counter({'PG-13': 22, 'R': 19, 'PG': 5, 'G': 1})

# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# Set data
df = pd.DataFrame({
'group': ['A'],
'Pg-13': [22],
'R': [19],
'PG': [5],
'G': [1],

})
 
# number of variable
categories=list(df)[1:]
N = len(categories)
 
# We are going to plot the first line of the data frame.
# But we need to repeat the first value to close the circular graph:
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
values
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories, color='grey', size=8)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([5,10,15,20,25], ["5","10","15",'20'], color="grey", size=7)
plt.ylim(0,25)
 
# Plot data
ax.plot(angles, values, linewidth=1, linestyle='solid')
 
# Fill area
ax.fill(angles, values, 'b', alpha=0.1)

# %%
plot_words = full[full['is_drama'] == True].plot_keywords

# %%
import numpy as np
d = []
import math
for i in plot_words:  
    d.append(i.split('|'))

# %%
full.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes', 'is_drama'],
#       dtype='object')

# %%
plot_words = plot_words.dropna()

# %%
m = [i for t in d for i in t]

# %%
cm = Counter(m)

# %%
df = pd.DataFrame.from_dict(cm, orient='index').reset_index()
df.to_csv('asd.csv')

# %%
full[['movie_title','imdb_score','duration','gross','title_year']].fillna(0).to_csv('bubble.csv')
